# %% [markdown]
# <a href="https://colab.research.google.com/github/TheRufael/CS770-Assignments/blob/main/Assignment_Three_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# Table of Contents
# 1. Reproducibility and versions
# 2. Imports and GPU check
# 3. Load Fashion MNIST and preprocess
# 4. Train and validation split with fixed seed
# 5. Utility functions for model building and evaluation
# 6. Define 10 configurations for systematic tuning
# 7. Train loop across configurations
# 8. Results table and quick summary

# %%
# ============================================================
# 1. Reproducibility and versions
#     Sets fixed seeds and reports library versions
# ============================================================

# Seed values used for reproducibility across executions
SEED = 42

import os, random, time
import numpy as np

random.seed(SEED)
np.random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)

import tensorflow as tf
tf.random.set_seed(SEED)

# Version logging for transparency and reproducibility
print("TensorFlow version", tf.__version__)

try:
    import pandas as pd
    print("Pandas version", pd.__version__)
except Exception:
    print("Pandas not found")

try:
    import sklearn
    print("Scikit-learn version", sklearn.__version__)
except Exception:
    print("Scikit-learn not found")
# Out:
# TensorFlow version 2.19.0
# Pandas version 2.2.2
# Scikit-learn version 1.6.1

# %%
# ============================================================
# 2. Imports and GPU check
#     Loads required modules and confirms hardware availability
# ============================================================

from tensorflow import keras
from tensorflow.keras import layers, regularizers, initializers, optimizers, utils
from sklearn.model_selection import train_test_split

# Displays available GPU devices for acceleration
print("GPU available", tf.config.list_physical_devices('GPU'))
# Out:
# GPU available [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ============================================================
# 3. Load Fashion MNIST and preprocess
#     Normalizes image data and applies one-hot encoding
# ============================================================

# Fashion MNIST dataset loading
(x_train_full, y_train_full), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalization of pixel intensity to [0, 1]
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# One-hot encoding of class labels
num_classes = 10
y_train_full_oh = utils.to_categorical(y_train_full, num_classes)
y_test_oh = utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# ============================================================
# 3. Load Fashion MNIST and preprocess
#     Normalizes image data and applies one-hot encoding
# ============================================================

# Fashion MNIST dataset loading
(x_train_full, y_train_full), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalization of pixel intensity to [0, 1]
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# One-hot encoding of class labels
num_classes = 10
y_train_full_oh = utils.to_categorical(y_train_full, num_classes)
y_test_oh = utils.to_categorical(y_test, num_classes)

# %%
# ============================================================
# 4. Train and validation split with fixed seed
#     Creates stratified 80/20 division for model evaluation
# ============================================================

x_train, x_val, y_train, y_val = train_test_split(
    x_train_full,
    y_train_full_oh,
    test_size=0.20,
    random_state=SEED,
    stratify=y_train_full  # Preserves label distribution
)

# Shape reporting for verification
print("Train shape", x_train.shape, "Val shape", x_val.shape, "Test shape", x_test.shape)
# Out:
# Train shape (48000, 28, 28) Val shape (12000, 28, 28) Test shape (10000, 28, 28)

# %%
# ============================================================
# 5. Utility functions
#     Includes model builder, compiler, parameter counter,
#     and evaluation helper
# ============================================================

# MLP architecture generator with configurable depth and regularization
def build_mlp(
    input_shape=(28, 28),
    hidden_units=(128, 64),
    activation="relu",
    kernel_init="he_normal",
    l2_reg=0.0,
    dropout_rate=0.0
):
    # Optional L2 regularizer
    l2 = regularizers.l2(l2_reg) if l2_reg and l2_reg > 0 else None
    init = initializers.get(kernel_init)

    model = keras.Sequential(name="mlp_fashion_mnist")
    model.add(layers.Input(shape=input_shape))
    model.add(layers.Flatten())  # Converts 2D image to vector form

    # Hidden dense layers
    for units in hidden_units:
        model.add(layers.Dense(units, activation=activation, kernel_initializer=init, kernel_regularizer=l2))
        if dropout_rate and dropout_rate > 0:
            model.add(layers.Dropout(dropout_rate))

    # Output layer using softmax for multi-class prediction
    model.add(layers.Dense(10, activation="softmax", kernel_initializer="glorot_uniform"))
    return model

# Model compilation helper with selectable optimizer
def compile_model(model, optimizer_name="adam", lr=1e-3):
    if optimizer_name == "adam":
        opt = optimizers.Adam(learning_rate=lr)
    elif optimizer_name == "sgd":
        opt = optimizers.SGD(learning_rate=lr, momentum=0.0)
    elif optimizer_name == "rmsprop":
        opt = optimizers.RMSprop(learning_rate=lr)
    else:
        opt = optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt, loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# Trainable parameter counter for model complexity analysis
def count_trainable_params(model):
    return int(np.sum([np.prod(v.shape) for v in model.trainable_variables]))

# Test-set evaluation helper returning accuracy
def evaluate_model(model, x_test, y_test_oh, batch_size=64):
    test_loss, test_acc = model.evaluate(x_test, y_test_oh, batch_size=batch_size, verbose=0)
    return test_acc

# %%
# ============================================================
# 6. Configurations for systematic hyperparameter tuning
#     Defines baseline model and nine variations
# ============================================================

BASELINE = {
    "name": "baseline",
    "hidden_units": (128, 64),
    "activation": "relu",
    "optimizer": "adam",
    "lr": 1e-3,
    "dropout": 0.0,
    "l2_reg": 0.0,
    "kernel_init": "he_normal",
    "batch_size": 64,
    "epochs": 30
}

# List of structured configurations used for controlled comparisons
CONFIGS = [
    BASELINE,
    {
        "name": "depth_3_layers",
        "hidden_units": (128, 64, 64),
        "activation": "relu",
        "optimizer": "adam",
        "lr": 1e-3,
        "dropout": 0.0,
        "l2_reg": 0.0,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
    {
        "name": "depth_4_layers",
        "hidden_units": (128, 128, 64, 32),
        "activation": "relu",
        "optimizer": "adam",
        "lr": 1e-3,
        "dropout": 0.0,
        "l2_reg": 0.0,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
    {
        "name": "units_larger",
        "hidden_units": (256, 128),
        "activation": "relu",
        "optimizer": "adam",
        "lr": 1e-3,
        "dropout": 0.0,
        "l2_reg": 0.0,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
    {
        "name": "units_smaller",
        "hidden_units": (64, 32),
        "activation": "relu",
        "optimizer": "adam",
        "lr": 1e-3,
        "dropout": 0.0,
        "l2_reg": 0.0,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
    {
        "name": "activation_tanh",
        "hidden_units": (128, 64),
        "activation": "tanh",
        "optimizer": "adam",
        "lr": 1e-3,
        "dropout": 0.0,
        "l2_reg": 0.0,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
    {
        "name": "optimizer_sgd",
        "hidden_units": (128, 64),
        "activation": "relu",
        "optimizer": "sgd",
        "lr": 1e-3,
        "dropout": 0.0,
        "l2_reg": 0.0,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
    {
        "name": "lr_0_01",
        "hidden_units": (128, 64),
        "activation": "relu",
        "optimizer": "adam",
        "lr": 1e-2,
        "dropout": 0.0,
        "l2_reg": 0.0,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
    {
        "name": "l2_1e_4",
        "hidden_units": (128, 64),
        "activation": "relu",
        "optimizer": "adam",
        "lr": 1e-3,
        "dropout": 0.0,
        "l2_reg": 1e-4,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
    {
        "name": "dropout_0_3",
        "hidden_units": (128, 64),
        "activation": "relu",
        "optimizer": "adam",
        "lr": 1e-3,
        "dropout": 0.3,
        "l2_reg": 0.0,
        "kernel_init": "he_normal",
        "batch_size": 64,
        "epochs": 30
    },
]

# %%
# ============================================================
# 7. Training loop
#     Executes models sequentially and records metrics
# ============================================================

results = []

for cfg in CONFIGS:
    print("\nRunning", cfg["name"])

    # Clears backend state before each training run
    tf.keras.backend.clear_session()

    # Model construction and compilation for current configuration
    model = build_mlp(
        input_shape=(28, 28),
        hidden_units=cfg["hidden_units"],
        activation=cfg["activation"],
        kernel_init=cfg["kernel_init"],
        l2_reg=cfg["l2_reg"],
        dropout_rate=cfg["dropout"]
    )
    model = compile_model(model, optimizer_name=cfg["optimizer"], lr=cfg["lr"])

    # Parameter count for complexity assessment
    params = count_trainable_params(model)

    # Training timer start
    start = time.time()

    # Model training with validation tracking
    hist = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=cfg["epochs"],
        batch_size=cfg["batch_size"],
        verbose=2
    )

    elapsed = time.time() - start

    # Accuracy extraction from history logs
    train_acc = float(hist.history["accuracy"][-1])
    val_acc = float(hist.history["val_accuracy"][-1])

    # Test-set performance measurement
    test_acc = float(evaluate_model(model, x_test, y_test_oh, batch_size=cfg["batch_size"]))

    # Results storage
    results.append({
        "config": cfg["name"],
        "hidden_units": str(cfg["hidden_units"]),
        "activation": cfg["activation"],
        "optimizer": cfg["optimizer"],
        "lr": cfg["lr"],
        "dropout": cfg["dropout"],
        "l2_reg": cfg["l2_reg"],
        "batch_size": cfg["batch_size"],
        "epochs": cfg["epochs"],
        "train_acc": round(train_acc, 4),
        "val_acc": round(val_acc, 4),
        "test_acc": round(test_acc, 4),
        "train_time_sec": int(elapsed),
        "trainable_params": params
    })
# Out:
# Running baseline
# Epoch 1/30
# 750/750 - 5s - 7ms/step - accuracy: 0.8121 - loss: 0.5351 - val_accuracy: 0.8558 - val_loss: 0.4080
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8602 - loss: 0.3881 - val_accuracy: 0.8657 - val_loss: 0.3760
# Epoch 3/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8727 - loss: 0.3476 - val_accuracy: 0.8767 - val_loss: 0.3431
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8803 - loss: 0.3232 - val_accuracy: 0.8776 - val_loss: 0.3365
# Epoch 5/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8872 - loss: 0.3027 - val_accuracy: 0.8826 - val_loss: 0.3276
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8930 - loss: 0.2876 - val_accuracy: 0.8826 - val_loss: 0.3274
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8997 - loss: 0.2716 - val_accuracy: 0.8851 - val_loss: 0.3215
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9036 - loss: 0.2594 - val_accuracy: 0.8839 - val_loss: 0.3266
# Epoch 9/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9076 - loss: 0.2493 - val_accuracy: 0.8828 - val_loss: 0.3337
# Epoch 10/30
# 750/750 - 4s - 6ms/step - accuracy: 0.9105 - loss: 0.2396 - val_accuracy: 0.8838 - val_loss: 0.3391
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9124 - loss: 0.2311 - val_accuracy: 0.8851 - val_loss: 0.3356
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9169 - loss: 0.2214 - val_accuracy: 0.8792 - val_loss: 0.3572
# Epoch 13/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9193 - loss: 0.2146 - val_accuracy: 0.8839 - val_loss: 0.3533
# Epoch 14/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9219 - loss: 0.2072 - val_accuracy: 0.8789 - val_loss: 0.3738
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9253 - loss: 0.1996 - val_accuracy: 0.8817 - val_loss: 0.3686
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9276 - loss: 0.1931 - val_accuracy: 0.8805 - val_loss: 0.3798
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9281 - loss: 0.1897 - val_accuracy: 0.8829 - val_loss: 0.3730
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9309 - loss: 0.1845 - val_accuracy: 0.8832 - val_loss: 0.3703
# Epoch 19/30
# 750/750 - 3s - 4ms/step - accuracy: 0.9335 - loss: 0.1758 - val_accuracy: 0.8861 - val_loss: 0.3820
# Epoch 20/30
# 750/750 - 4s - 6ms/step - accuracy: 0.9360 - loss: 0.1714 - val_accuracy: 0.8835 - val_loss: 0.3835
# Epoch 21/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9374 - loss: 0.1667 - val_accuracy: 0.8852 - val_loss: 0.3834
# Epoch 22/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9391 - loss: 0.1598 - val_accuracy: 0.8865 - val_loss: 0.3827
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9430 - loss: 0.1532 - val_accuracy: 0.8853 - val_loss: 0.3984
# Epoch 24/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9428 - loss: 0.1527 - val_accuracy: 0.8867 - val_loss: 0.3975
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9444 - loss: 0.1477 - val_accuracy: 0.8874 - val_loss: 0.3930
# Epoch 26/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9463 - loss: 0.1418 - val_accuracy: 0.8898 - val_loss: 0.4051
# Epoch 27/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9465 - loss: 0.1394 - val_accuracy: 0.8879 - val_loss: 0.4205
# Epoch 28/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9482 - loss: 0.1365 - val_accuracy: 0.8830 - val_loss: 0.4334
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9501 - loss: 0.1330 - val_accuracy: 0.8915 - val_loss: 0.4093
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9499 - loss: 0.1315 - val_accuracy: 0.8872 - val_loss: 0.4284
#
# Running depth_3_layers
# Epoch 1/30
# 750/750 - 5s - 6ms/step - accuracy: 0.8097 - loss: 0.5376 - val_accuracy: 0.8583 - val_loss: 0.3983
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8581 - loss: 0.3880 - val_accuracy: 0.8706 - val_loss: 0.3568
# Epoch 3/30
# 750/750 - 3s - 4ms/step - accuracy: 0.8724 - loss: 0.3443 - val_accuracy: 0.8775 - val_loss: 0.3371
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8809 - loss: 0.3196 - val_accuracy: 0.8788 - val_loss: 0.3325
# Epoch 5/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8886 - loss: 0.3008 - val_accuracy: 0.8806 - val_loss: 0.3259
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8947 - loss: 0.2831 - val_accuracy: 0.8817 - val_loss: 0.3339
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8994 - loss: 0.2687 - val_accuracy: 0.8823 - val_loss: 0.3435
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9030 - loss: 0.2579 - val_accuracy: 0.8816 - val_loss: 0.3428
# Epoch 9/30
# 750/750 - 3s - 4ms/step - accuracy: 0.9064 - loss: 0.2481 - val_accuracy: 0.8804 - val_loss: 0.3582
# Epoch 10/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9087 - loss: 0.2407 - val_accuracy: 0.8868 - val_loss: 0.3360
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9132 - loss: 0.2312 - val_accuracy: 0.8860 - val_loss: 0.3422
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9162 - loss: 0.2230 - val_accuracy: 0.8877 - val_loss: 0.3396
# Epoch 13/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9196 - loss: 0.2131 - val_accuracy: 0.8899 - val_loss: 0.3360
# Epoch 14/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9207 - loss: 0.2093 - val_accuracy: 0.8875 - val_loss: 0.3392
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9225 - loss: 0.2040 - val_accuracy: 0.8903 - val_loss: 0.3612
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9244 - loss: 0.1988 - val_accuracy: 0.8918 - val_loss: 0.3541
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9290 - loss: 0.1876 - val_accuracy: 0.8949 - val_loss: 0.3541
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9293 - loss: 0.1849 - val_accuracy: 0.8896 - val_loss: 0.3846
# Epoch 19/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9316 - loss: 0.1781 - val_accuracy: 0.8871 - val_loss: 0.4167
# Epoch 20/30
# 750/750 - 3s - 4ms/step - accuracy: 0.9321 - loss: 0.1766 - val_accuracy: 0.8926 - val_loss: 0.3982
# Epoch 21/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9340 - loss: 0.1727 - val_accuracy: 0.8924 - val_loss: 0.3740
# Epoch 22/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9351 - loss: 0.1695 - val_accuracy: 0.8900 - val_loss: 0.4005
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9389 - loss: 0.1601 - val_accuracy: 0.8876 - val_loss: 0.4241
# Epoch 24/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9385 - loss: 0.1585 - val_accuracy: 0.8933 - val_loss: 0.4276
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9400 - loss: 0.1580 - val_accuracy: 0.8921 - val_loss: 0.4088
# Epoch 26/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9428 - loss: 0.1503 - val_accuracy: 0.8899 - val_loss: 0.4285
# Epoch 27/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9433 - loss: 0.1455 - val_accuracy: 0.8903 - val_loss: 0.4340
# Epoch 28/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9428 - loss: 0.1455 - val_accuracy: 0.8910 - val_loss: 0.4549
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9428 - loss: 0.1501 - val_accuracy: 0.8926 - val_loss: 0.4778
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9465 - loss: 0.1371 - val_accuracy: 0.8921 - val_loss: 0.4910
#
# Running depth_4_layers
# Epoch 1/30
# 750/750 - 6s - 8ms/step - accuracy: 0.8078 - loss: 0.5424 - val_accuracy: 0.8486 - val_loss: 0.4197
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8592 - loss: 0.3827 - val_accuracy: 0.8633 - val_loss: 0.3790
# Epoch 3/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8723 - loss: 0.3450 - val_accuracy: 0.8727 - val_loss: 0.3450
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8812 - loss: 0.3189 - val_accuracy: 0.8779 - val_loss: 0.3367
# Epoch 5/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8887 - loss: 0.2987 - val_accuracy: 0.8768 - val_loss: 0.3332
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8929 - loss: 0.2851 - val_accuracy: 0.8840 - val_loss: 0.3225
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8992 - loss: 0.2701 - val_accuracy: 0.8861 - val_loss: 0.3238
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9027 - loss: 0.2597 - val_accuracy: 0.8823 - val_loss: 0.3430
# Epoch 9/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9056 - loss: 0.2504 - val_accuracy: 0.8869 - val_loss: 0.3346
# Epoch 10/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9089 - loss: 0.2398 - val_accuracy: 0.8892 - val_loss: 0.3358
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9123 - loss: 0.2322 - val_accuracy: 0.8878 - val_loss: 0.3410
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9159 - loss: 0.2222 - val_accuracy: 0.8824 - val_loss: 0.3684
# Epoch 13/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9181 - loss: 0.2170 - val_accuracy: 0.8839 - val_loss: 0.3628
# Epoch 14/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9203 - loss: 0.2114 - val_accuracy: 0.8869 - val_loss: 0.3601
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9236 - loss: 0.2013 - val_accuracy: 0.8874 - val_loss: 0.3638
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9251 - loss: 0.1939 - val_accuracy: 0.8866 - val_loss: 0.3714
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9279 - loss: 0.1889 - val_accuracy: 0.8895 - val_loss: 0.3810
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9302 - loss: 0.1819 - val_accuracy: 0.8898 - val_loss: 0.3792
# Epoch 19/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9302 - loss: 0.1779 - val_accuracy: 0.8894 - val_loss: 0.3873
# Epoch 20/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9324 - loss: 0.1775 - val_accuracy: 0.8889 - val_loss: 0.3862
# Epoch 21/30
# 750/750 - 3s - 4ms/step - accuracy: 0.9345 - loss: 0.1723 - val_accuracy: 0.8919 - val_loss: 0.3785
# Epoch 22/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9367 - loss: 0.1649 - val_accuracy: 0.8891 - val_loss: 0.4081
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9389 - loss: 0.1571 - val_accuracy: 0.8883 - val_loss: 0.4289
# Epoch 24/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9397 - loss: 0.1554 - val_accuracy: 0.8895 - val_loss: 0.4108
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9396 - loss: 0.1572 - val_accuracy: 0.8896 - val_loss: 0.4306
# Epoch 26/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9416 - loss: 0.1483 - val_accuracy: 0.8887 - val_loss: 0.4324
# Epoch 27/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9427 - loss: 0.1458 - val_accuracy: 0.8890 - val_loss: 0.4474
# Epoch 28/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9443 - loss: 0.1443 - val_accuracy: 0.8931 - val_loss: 0.4532
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9443 - loss: 0.1421 - val_accuracy: 0.8884 - val_loss: 0.4670
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9447 - loss: 0.1399 - val_accuracy: 0.8856 - val_loss: 0.4699
#
# Running units_larger
# Epoch 1/30
# 750/750 - 5s - 7ms/step - accuracy: 0.8168 - loss: 0.5124 - val_accuracy: 0.8560 - val_loss: 0.4053
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8610 - loss: 0.3778 - val_accuracy: 0.8702 - val_loss: 0.3590
# Epoch 3/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8764 - loss: 0.3344 - val_accuracy: 0.8721 - val_loss: 0.3481
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8855 - loss: 0.3076 - val_accuracy: 0.8738 - val_loss: 0.3406
# Epoch 5/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8939 - loss: 0.2851 - val_accuracy: 0.8767 - val_loss: 0.3363
# Epoch 6/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8999 - loss: 0.2681 - val_accuracy: 0.8798 - val_loss: 0.3299
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9044 - loss: 0.2536 - val_accuracy: 0.8825 - val_loss: 0.3331
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9107 - loss: 0.2405 - val_accuracy: 0.8873 - val_loss: 0.3241
# Epoch 9/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9140 - loss: 0.2284 - val_accuracy: 0.8890 - val_loss: 0.3355
# Epoch 10/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9175 - loss: 0.2192 - val_accuracy: 0.8857 - val_loss: 0.3434
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9215 - loss: 0.2114 - val_accuracy: 0.8809 - val_loss: 0.3608
# Epoch 12/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9246 - loss: 0.2013 - val_accuracy: 0.8863 - val_loss: 0.3600
# Epoch 13/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9277 - loss: 0.1914 - val_accuracy: 0.8845 - val_loss: 0.3728
# Epoch 14/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9315 - loss: 0.1808 - val_accuracy: 0.8875 - val_loss: 0.3696
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9343 - loss: 0.1740 - val_accuracy: 0.8850 - val_loss: 0.4066
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9357 - loss: 0.1682 - val_accuracy: 0.8903 - val_loss: 0.3710
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9397 - loss: 0.1587 - val_accuracy: 0.8931 - val_loss: 0.3890
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9410 - loss: 0.1540 - val_accuracy: 0.8903 - val_loss: 0.3858
# Epoch 19/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9441 - loss: 0.1464 - val_accuracy: 0.8929 - val_loss: 0.4069
# Epoch 20/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9457 - loss: 0.1421 - val_accuracy: 0.8925 - val_loss: 0.4132
# Epoch 21/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9485 - loss: 0.1365 - val_accuracy: 0.8919 - val_loss: 0.4270
# Epoch 22/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9496 - loss: 0.1324 - val_accuracy: 0.8905 - val_loss: 0.4355
# Epoch 23/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9490 - loss: 0.1320 - val_accuracy: 0.8883 - val_loss: 0.4421
# Epoch 24/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9523 - loss: 0.1257 - val_accuracy: 0.8858 - val_loss: 0.4612
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9537 - loss: 0.1218 - val_accuracy: 0.8857 - val_loss: 0.4802
# Epoch 26/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9534 - loss: 0.1215 - val_accuracy: 0.8849 - val_loss: 0.4990
# Epoch 27/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9544 - loss: 0.1195 - val_accuracy: 0.8853 - val_loss: 0.5021
# Epoch 28/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9558 - loss: 0.1148 - val_accuracy: 0.8815 - val_loss: 0.5068
# Epoch 29/30
# 750/750 - 3s - 4ms/step - accuracy: 0.9596 - loss: 0.1064 - val_accuracy: 0.8834 - val_loss: 0.5426
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9596 - loss: 0.1035 - val_accuracy: 0.8837 - val_loss: 0.5393
#
# Running units_smaller
# Epoch 1/30
# 750/750 - 4s - 6ms/step - accuracy: 0.8019 - loss: 0.5703 - val_accuracy: 0.8442 - val_loss: 0.4479
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8544 - loss: 0.4111 - val_accuracy: 0.8620 - val_loss: 0.3950
# Epoch 3/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8665 - loss: 0.3709 - val_accuracy: 0.8693 - val_loss: 0.3639
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8748 - loss: 0.3447 - val_accuracy: 0.8736 - val_loss: 0.3548
# Epoch 5/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8821 - loss: 0.3258 - val_accuracy: 0.8792 - val_loss: 0.3408
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8872 - loss: 0.3100 - val_accuracy: 0.8783 - val_loss: 0.3402
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8920 - loss: 0.2967 - val_accuracy: 0.8808 - val_loss: 0.3358
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8962 - loss: 0.2859 - val_accuracy: 0.8831 - val_loss: 0.3332
# Epoch 9/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8991 - loss: 0.2763 - val_accuracy: 0.8853 - val_loss: 0.3304
# Epoch 10/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9019 - loss: 0.2681 - val_accuracy: 0.8836 - val_loss: 0.3417
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9059 - loss: 0.2595 - val_accuracy: 0.8792 - val_loss: 0.3466
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9079 - loss: 0.2529 - val_accuracy: 0.8794 - val_loss: 0.3501
# Epoch 13/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9107 - loss: 0.2461 - val_accuracy: 0.8788 - val_loss: 0.3551
# Epoch 14/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9122 - loss: 0.2398 - val_accuracy: 0.8759 - val_loss: 0.3719
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9147 - loss: 0.2330 - val_accuracy: 0.8809 - val_loss: 0.3616
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9165 - loss: 0.2261 - val_accuracy: 0.8775 - val_loss: 0.3826
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9188 - loss: 0.2217 - val_accuracy: 0.8809 - val_loss: 0.3711
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9204 - loss: 0.2161 - val_accuracy: 0.8841 - val_loss: 0.3641
# Epoch 19/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9233 - loss: 0.2100 - val_accuracy: 0.8821 - val_loss: 0.3709
# Epoch 20/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9240 - loss: 0.2069 - val_accuracy: 0.8815 - val_loss: 0.3765
# Epoch 21/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9256 - loss: 0.2022 - val_accuracy: 0.8828 - val_loss: 0.3832
# Epoch 22/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9273 - loss: 0.1978 - val_accuracy: 0.8839 - val_loss: 0.3759
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9278 - loss: 0.1942 - val_accuracy: 0.8788 - val_loss: 0.3925
# Epoch 24/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9304 - loss: 0.1903 - val_accuracy: 0.8853 - val_loss: 0.3810
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9314 - loss: 0.1859 - val_accuracy: 0.8817 - val_loss: 0.3922
# Epoch 26/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9328 - loss: 0.1838 - val_accuracy: 0.8815 - val_loss: 0.3904
# Epoch 27/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9348 - loss: 0.1774 - val_accuracy: 0.8827 - val_loss: 0.3924
# Epoch 28/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9362 - loss: 0.1745 - val_accuracy: 0.8807 - val_loss: 0.4105
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9370 - loss: 0.1726 - val_accuracy: 0.8802 - val_loss: 0.4174
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9372 - loss: 0.1699 - val_accuracy: 0.8781 - val_loss: 0.4185
#
# Running activation_tanh
# Epoch 1/30
# 750/750 - 4s - 6ms/step - accuracy: 0.8187 - loss: 0.5133 - val_accuracy: 0.8575 - val_loss: 0.3997
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8631 - loss: 0.3770 - val_accuracy: 0.8712 - val_loss: 0.3555
# Epoch 3/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8760 - loss: 0.3386 - val_accuracy: 0.8773 - val_loss: 0.3354
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8847 - loss: 0.3139 - val_accuracy: 0.8796 - val_loss: 0.3247
# Epoch 5/30
# 750/750 - 3s - 4ms/step - accuracy: 0.8920 - loss: 0.2940 - val_accuracy: 0.8824 - val_loss: 0.3188
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8976 - loss: 0.2775 - val_accuracy: 0.8835 - val_loss: 0.3163
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9032 - loss: 0.2631 - val_accuracy: 0.8852 - val_loss: 0.3182
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9079 - loss: 0.2497 - val_accuracy: 0.8865 - val_loss: 0.3185
# Epoch 9/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9125 - loss: 0.2377 - val_accuracy: 0.8875 - val_loss: 0.3211
# Epoch 10/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9159 - loss: 0.2276 - val_accuracy: 0.8853 - val_loss: 0.3239
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9189 - loss: 0.2200 - val_accuracy: 0.8837 - val_loss: 0.3327
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9237 - loss: 0.2099 - val_accuracy: 0.8814 - val_loss: 0.3373
# Epoch 13/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9251 - loss: 0.2028 - val_accuracy: 0.8829 - val_loss: 0.3391
# Epoch 14/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9285 - loss: 0.1956 - val_accuracy: 0.8860 - val_loss: 0.3375
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9309 - loss: 0.1876 - val_accuracy: 0.8852 - val_loss: 0.3425
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9341 - loss: 0.1799 - val_accuracy: 0.8829 - val_loss: 0.3469
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9354 - loss: 0.1759 - val_accuracy: 0.8856 - val_loss: 0.3493
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9377 - loss: 0.1699 - val_accuracy: 0.8860 - val_loss: 0.3500
# Epoch 19/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9401 - loss: 0.1639 - val_accuracy: 0.8864 - val_loss: 0.3580
# Epoch 20/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9422 - loss: 0.1606 - val_accuracy: 0.8861 - val_loss: 0.3614
# Epoch 21/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9428 - loss: 0.1557 - val_accuracy: 0.8867 - val_loss: 0.3628
# Epoch 22/30
# 750/750 - 3s - 4ms/step - accuracy: 0.9426 - loss: 0.1555 - val_accuracy: 0.8866 - val_loss: 0.3656
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9463 - loss: 0.1481 - val_accuracy: 0.8855 - val_loss: 0.3690
# Epoch 24/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9486 - loss: 0.1429 - val_accuracy: 0.8858 - val_loss: 0.3785
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9487 - loss: 0.1433 - val_accuracy: 0.8863 - val_loss: 0.3793
# Epoch 26/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9504 - loss: 0.1384 - val_accuracy: 0.8878 - val_loss: 0.3870
# Epoch 27/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9517 - loss: 0.1345 - val_accuracy: 0.8865 - val_loss: 0.3878
# Epoch 28/30
# 750/750 - 3s - 3ms/step - accuracy: 0.9512 - loss: 0.1347 - val_accuracy: 0.8887 - val_loss: 0.3804
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9523 - loss: 0.1317 - val_accuracy: 0.8863 - val_loss: 0.3939
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9523 - loss: 0.1303 - val_accuracy: 0.8887 - val_loss: 0.3920
#
# Running optimizer_sgd
# Epoch 1/30
# 750/750 - 4s - 5ms/step - accuracy: 0.4606 - loss: 1.8037 - val_accuracy: 0.6367 - val_loss: 1.4012
# Epoch 2/30
# 750/750 - 4s - 5ms/step - accuracy: 0.6690 - loss: 1.1725 - val_accuracy: 0.6971 - val_loss: 1.0120
# Epoch 3/30
# 750/750 - 2s - 3ms/step - accuracy: 0.7137 - loss: 0.9262 - val_accuracy: 0.7322 - val_loss: 0.8578
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.7387 - loss: 0.8176 - val_accuracy: 0.7524 - val_loss: 0.7776
# Epoch 5/30
# 750/750 - 2s - 2ms/step - accuracy: 0.7555 - loss: 0.7544 - val_accuracy: 0.7646 - val_loss: 0.7248
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.7686 - loss: 0.7102 - val_accuracy: 0.7763 - val_loss: 0.6859
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.7776 - loss: 0.6765 - val_accuracy: 0.7843 - val_loss: 0.6554
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.7853 - loss: 0.6495 - val_accuracy: 0.7914 - val_loss: 0.6307
# Epoch 9/30
# 750/750 - 2s - 3ms/step - accuracy: 0.7915 - loss: 0.6273 - val_accuracy: 0.7976 - val_loss: 0.6101
# Epoch 10/30
# 750/750 - 2s - 2ms/step - accuracy: 0.7974 - loss: 0.6086 - val_accuracy: 0.8032 - val_loss: 0.5926
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8025 - loss: 0.5926 - val_accuracy: 0.8072 - val_loss: 0.5776
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8070 - loss: 0.5787 - val_accuracy: 0.8115 - val_loss: 0.5645
# Epoch 13/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8109 - loss: 0.5665 - val_accuracy: 0.8162 - val_loss: 0.5530
# Epoch 14/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8143 - loss: 0.5556 - val_accuracy: 0.8188 - val_loss: 0.5427
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8164 - loss: 0.5460 - val_accuracy: 0.8214 - val_loss: 0.5335
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8189 - loss: 0.5372 - val_accuracy: 0.8242 - val_loss: 0.5252
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8215 - loss: 0.5293 - val_accuracy: 0.8251 - val_loss: 0.5176
# Epoch 18/30
# 750/750 - 2s - 2ms/step - accuracy: 0.8232 - loss: 0.5221 - val_accuracy: 0.8278 - val_loss: 0.5107
# Epoch 19/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8254 - loss: 0.5155 - val_accuracy: 0.8289 - val_loss: 0.5044
# Epoch 20/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8271 - loss: 0.5094 - val_accuracy: 0.8314 - val_loss: 0.4986
# Epoch 21/30
# 750/750 - 2s - 2ms/step - accuracy: 0.8286 - loss: 0.5038 - val_accuracy: 0.8341 - val_loss: 0.4931
# Epoch 22/30
# 750/750 - 2s - 2ms/step - accuracy: 0.8296 - loss: 0.4986 - val_accuracy: 0.8357 - val_loss: 0.4881
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8311 - loss: 0.4937 - val_accuracy: 0.8356 - val_loss: 0.4835
# Epoch 24/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8323 - loss: 0.4891 - val_accuracy: 0.8370 - val_loss: 0.4792
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8334 - loss: 0.4848 - val_accuracy: 0.8374 - val_loss: 0.4751
# Epoch 26/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8347 - loss: 0.4807 - val_accuracy: 0.8385 - val_loss: 0.4713
# Epoch 27/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8360 - loss: 0.4769 - val_accuracy: 0.8389 - val_loss: 0.4677
# Epoch 28/30
# 750/750 - 2s - 2ms/step - accuracy: 0.8367 - loss: 0.4733 - val_accuracy: 0.8407 - val_loss: 0.4644
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8375 - loss: 0.4698 - val_accuracy: 0.8422 - val_loss: 0.4611
# Epoch 30/30
# 750/750 - 2s - 2ms/step - accuracy: 0.8387 - loss: 0.4665 - val_accuracy: 0.8431 - val_loss: 0.4581
#
# Running lr_0_01
# Epoch 1/30
# 750/750 - 4s - 6ms/step - accuracy: 0.8009 - loss: 0.5532 - val_accuracy: 0.8115 - val_loss: 0.4830
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8445 - loss: 0.4236 - val_accuracy: 0.8486 - val_loss: 0.4156
# Epoch 3/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8549 - loss: 0.3951 - val_accuracy: 0.8636 - val_loss: 0.3826
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8619 - loss: 0.3786 - val_accuracy: 0.8702 - val_loss: 0.3834
# Epoch 5/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8643 - loss: 0.3712 - val_accuracy: 0.8634 - val_loss: 0.4067
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8699 - loss: 0.3544 - val_accuracy: 0.8713 - val_loss: 0.3661
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8730 - loss: 0.3522 - val_accuracy: 0.8677 - val_loss: 0.3843
# Epoch 8/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8751 - loss: 0.3447 - val_accuracy: 0.8778 - val_loss: 0.3580
# Epoch 9/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8774 - loss: 0.3379 - val_accuracy: 0.8756 - val_loss: 0.3659
# Epoch 10/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8791 - loss: 0.3333 - val_accuracy: 0.8733 - val_loss: 0.3799
# Epoch 11/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8802 - loss: 0.3314 - val_accuracy: 0.8736 - val_loss: 0.3816
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8829 - loss: 0.3226 - val_accuracy: 0.8750 - val_loss: 0.3706
# Epoch 13/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8825 - loss: 0.3186 - val_accuracy: 0.8726 - val_loss: 0.4029
# Epoch 14/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8838 - loss: 0.3210 - val_accuracy: 0.8740 - val_loss: 0.3937
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8839 - loss: 0.3128 - val_accuracy: 0.8673 - val_loss: 0.4155
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8840 - loss: 0.3193 - val_accuracy: 0.8767 - val_loss: 0.3773
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8880 - loss: 0.3049 - val_accuracy: 0.8707 - val_loss: 0.4155
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8883 - loss: 0.3071 - val_accuracy: 0.8700 - val_loss: 0.4296
# Epoch 19/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8868 - loss: 0.3101 - val_accuracy: 0.8643 - val_loss: 0.4289
# Epoch 20/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8876 - loss: 0.3065 - val_accuracy: 0.8788 - val_loss: 0.3877
# Epoch 21/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8884 - loss: 0.3048 - val_accuracy: 0.8730 - val_loss: 0.4022
# Epoch 22/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8901 - loss: 0.2990 - val_accuracy: 0.8739 - val_loss: 0.4073
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8925 - loss: 0.2967 - val_accuracy: 0.8624 - val_loss: 0.4622
# Epoch 24/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8918 - loss: 0.2961 - val_accuracy: 0.8714 - val_loss: 0.4205
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8910 - loss: 0.2965 - val_accuracy: 0.8802 - val_loss: 0.4115
# Epoch 26/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8938 - loss: 0.2902 - val_accuracy: 0.8771 - val_loss: 0.4086
# Epoch 27/30
# 750/750 - 3s - 4ms/step - accuracy: 0.8897 - loss: 0.2998 - val_accuracy: 0.8699 - val_loss: 0.4736
# Epoch 28/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8929 - loss: 0.2922 - val_accuracy: 0.8763 - val_loss: 0.4165
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8953 - loss: 0.2883 - val_accuracy: 0.8726 - val_loss: 0.4423
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8914 - loss: 0.2959 - val_accuracy: 0.8729 - val_loss: 0.4456
#
# Running l2_1e_4
# Epoch 1/30
# 750/750 - 6s - 8ms/step - accuracy: 0.8084 - loss: 0.5821 - val_accuracy: 0.8514 - val_loss: 0.4631
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8585 - loss: 0.4341 - val_accuracy: 0.8683 - val_loss: 0.4103
# Epoch 3/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8702 - loss: 0.3966 - val_accuracy: 0.8712 - val_loss: 0.3955
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8789 - loss: 0.3740 - val_accuracy: 0.8765 - val_loss: 0.3822
# Epoch 5/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8849 - loss: 0.3577 - val_accuracy: 0.8824 - val_loss: 0.3703
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8905 - loss: 0.3451 - val_accuracy: 0.8842 - val_loss: 0.3699
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8935 - loss: 0.3366 - val_accuracy: 0.8855 - val_loss: 0.3699
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8971 - loss: 0.3277 - val_accuracy: 0.8857 - val_loss: 0.3727
# Epoch 9/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8999 - loss: 0.3196 - val_accuracy: 0.8813 - val_loss: 0.3791
# Epoch 10/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9038 - loss: 0.3135 - val_accuracy: 0.8857 - val_loss: 0.3768
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9067 - loss: 0.3066 - val_accuracy: 0.8869 - val_loss: 0.3785
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9076 - loss: 0.3012 - val_accuracy: 0.8872 - val_loss: 0.3807
# Epoch 13/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9120 - loss: 0.2969 - val_accuracy: 0.8861 - val_loss: 0.3829
# Epoch 14/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9129 - loss: 0.2912 - val_accuracy: 0.8882 - val_loss: 0.3803
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9148 - loss: 0.2862 - val_accuracy: 0.8863 - val_loss: 0.3870
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9179 - loss: 0.2807 - val_accuracy: 0.8888 - val_loss: 0.3840
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9176 - loss: 0.2781 - val_accuracy: 0.8900 - val_loss: 0.3884
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9194 - loss: 0.2761 - val_accuracy: 0.8830 - val_loss: 0.4036
# Epoch 19/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9219 - loss: 0.2725 - val_accuracy: 0.8847 - val_loss: 0.3979
# Epoch 20/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9236 - loss: 0.2652 - val_accuracy: 0.8856 - val_loss: 0.4079
# Epoch 21/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9262 - loss: 0.2635 - val_accuracy: 0.8814 - val_loss: 0.4240
# Epoch 22/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9267 - loss: 0.2606 - val_accuracy: 0.8783 - val_loss: 0.4265
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9280 - loss: 0.2572 - val_accuracy: 0.8857 - val_loss: 0.4121
# Epoch 24/30
# 750/750 - 3s - 4ms/step - accuracy: 0.9284 - loss: 0.2575 - val_accuracy: 0.8831 - val_loss: 0.4189
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9281 - loss: 0.2567 - val_accuracy: 0.8867 - val_loss: 0.4056
# Epoch 26/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9306 - loss: 0.2519 - val_accuracy: 0.8885 - val_loss: 0.4248
# Epoch 27/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9314 - loss: 0.2517 - val_accuracy: 0.8887 - val_loss: 0.4108
# Epoch 28/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9307 - loss: 0.2524 - val_accuracy: 0.8875 - val_loss: 0.4166
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9324 - loss: 0.2495 - val_accuracy: 0.8874 - val_loss: 0.4217
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.9339 - loss: 0.2472 - val_accuracy: 0.8850 - val_loss: 0.4312
#
# Running dropout_0_3
# Epoch 1/30
# 750/750 - 5s - 6ms/step - accuracy: 0.7407 - loss: 0.7277 - val_accuracy: 0.8418 - val_loss: 0.4421
# Epoch 2/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8221 - loss: 0.4979 - val_accuracy: 0.8614 - val_loss: 0.3907
# Epoch 3/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8377 - loss: 0.4523 - val_accuracy: 0.8643 - val_loss: 0.3784
# Epoch 4/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8487 - loss: 0.4205 - val_accuracy: 0.8679 - val_loss: 0.3619
# Epoch 5/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8539 - loss: 0.4022 - val_accuracy: 0.8760 - val_loss: 0.3458
# Epoch 6/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8595 - loss: 0.3893 - val_accuracy: 0.8760 - val_loss: 0.3423
# Epoch 7/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8617 - loss: 0.3806 - val_accuracy: 0.8827 - val_loss: 0.3309
# Epoch 8/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8660 - loss: 0.3656 - val_accuracy: 0.8808 - val_loss: 0.3277
# Epoch 9/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8704 - loss: 0.3536 - val_accuracy: 0.8842 - val_loss: 0.3254
# Epoch 10/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8727 - loss: 0.3472 - val_accuracy: 0.8838 - val_loss: 0.3254
# Epoch 11/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8750 - loss: 0.3392 - val_accuracy: 0.8860 - val_loss: 0.3209
# Epoch 12/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8788 - loss: 0.3331 - val_accuracy: 0.8838 - val_loss: 0.3160
# Epoch 13/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8777 - loss: 0.3298 - val_accuracy: 0.8853 - val_loss: 0.3205
# Epoch 14/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8809 - loss: 0.3245 - val_accuracy: 0.8830 - val_loss: 0.3235
# Epoch 15/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8828 - loss: 0.3195 - val_accuracy: 0.8844 - val_loss: 0.3229
# Epoch 16/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8838 - loss: 0.3144 - val_accuracy: 0.8857 - val_loss: 0.3176
# Epoch 17/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8868 - loss: 0.3073 - val_accuracy: 0.8862 - val_loss: 0.3184
# Epoch 18/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8864 - loss: 0.3071 - val_accuracy: 0.8896 - val_loss: 0.3184
# Epoch 19/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8864 - loss: 0.3028 - val_accuracy: 0.8902 - val_loss: 0.3156
# Epoch 20/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8879 - loss: 0.3014 - val_accuracy: 0.8905 - val_loss: 0.3171
# Epoch 21/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8907 - loss: 0.2938 - val_accuracy: 0.8892 - val_loss: 0.3183
# Epoch 22/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8923 - loss: 0.2905 - val_accuracy: 0.8908 - val_loss: 0.3195
# Epoch 23/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8907 - loss: 0.2928 - val_accuracy: 0.8909 - val_loss: 0.3229
# Epoch 24/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8921 - loss: 0.2896 - val_accuracy: 0.8913 - val_loss: 0.3143
# Epoch 25/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8941 - loss: 0.2851 - val_accuracy: 0.8911 - val_loss: 0.3138
# Epoch 26/30
# 750/750 - 3s - 3ms/step - accuracy: 0.8944 - loss: 0.2813 - val_accuracy: 0.8909 - val_loss: 0.3153
# Epoch 27/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8944 - loss: 0.2814 - val_accuracy: 0.8904 - val_loss: 0.3177
# Epoch 28/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8971 - loss: 0.2745 - val_accuracy: 0.8927 - val_loss: 0.3194
# Epoch 29/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8973 - loss: 0.2770 - val_accuracy: 0.8903 - val_loss: 0.3187
# Epoch 30/30
# 750/750 - 2s - 3ms/step - accuracy: 0.8964 - loss: 0.2768 - val_accuracy: 0.8883 - val_loss: 0.3338

# %%
# ============================================================
# 8. Results table and summary
#     Displays validation ranking and performance metrics
# ============================================================

try:
    import pandas as pd

    df_results = pd.DataFrame(results)
    df_display = df_results.sort_values("val_acc", ascending=False).reset_index(drop=True)

    print("\nTop results by validation accuracy")

    from IPython.display import display
    display(df_display)

except Exception:
    print("Install pandas for tabular display")
    for r in sorted(results, key=lambda x: x["val_acc"], reverse=True):
        print(r)
# Out:
# Top results by validation accuracy
#             config        hidden_units activation optimizer     lr  dropout  \
# 0   depth_3_layers       (128, 64, 64)       relu      adam  0.001      0.0
# 1  activation_tanh           (128, 64)       tanh      adam  0.001      0.0
# 2      dropout_0_3           (128, 64)       relu      adam  0.001      0.3
# 3         baseline           (128, 64)       relu      adam  0.001      0.0
# 4   depth_4_layers  (128, 128, 64, 32)       relu      adam  0.001      0.0
# 5          l2_1e_4           (128, 64)       relu      adam  0.001      0.0
# 6     units_larger          (256, 128)       relu      adam  0.001      0.0
# 7    units_smaller            (64, 32)       relu      adam  0.001      0.0
# 8          lr_0_01           (128, 64)       relu      adam  0.010      0.0
# 9    optimizer_sgd           (128, 64)       relu       sgd  0.001      0.0
#
#    l2_reg  batch_size  epochs  train_acc  val_acc  test_acc  train_time_sec  \
# 0  0.0000          64      30     0.9465   0.8921    0.8769              66
# 1  0.0000          64      30     0.9523   0.8887    0.8750              66
# 2  0.0000          64      30     0.8964   0.8883    0.8779              66
# 3  0.0000          64      30     0.9499   0.8872    0.8793              72
# 4  0.0000          64      30     0.9447   0.8856    0.8737              70
# 5  0.0001          64      30     0.9339   0.8850    0.8711              67
# 6  0.0000          64      30     0.9596   0.8837    0.8731              66
# 7  0.0000          64      30     0.9372   0.8781    0.8688              66
# 8  0.0000          64      30     0.8914   0.8729    0.8570              67
# 9  0.0000          64      30     0.8387   0.8431    0.8290              63
#
#    trainable_params
# 0            113546
# 1            109386
# 2            109386
# 3            109386
# 4            127658
# 5            109386
# 6            235146
# 7             52650
# 8            109386
# 9            109386
